# %%
#Pandas melt function is used to transform or reshape data.
#Syntax : pandas.melt()
# Parameters:
#     Frame 
#     id_vars
#     value_name
#     value_vars
#     var_name

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\CSV\movies.csv")
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
pd.melt(frame=df)
# Out:
#     variable                               value
# 0       Film          Zack and Miri Make a Porno
# 1       Film                     Youth in Revolt
# 2       Film  You Will Meet a Tall Dark Stranger
# 3       Film                        When in Rome
# 4       Film               What Happens in Vegas
# ..       ...                                 ...
# 611     Year                                2007
# 612     Year                                2009
# 613     Year                                2011
# 614     Year                                2008
# 615     Year                                2009
#
# [616 rows x 2 columns]

# %%
pd.melt(frame =df,id_vars =['Genre'])
# Out:
#        Genre variable                               value
# 0    Romance     Film          Zack and Miri Make a Porno
# 1     Comedy     Film                     Youth in Revolt
# 2     Comedy     Film  You Will Meet a Tall Dark Stranger
# 3     Comedy     Film                        When in Rome
# 4     Comedy     Film               What Happens in Vegas
# ..       ...      ...                                 ...
# 534  romance     Year                                2007
# 535    Drama     Year                                2009
# 536    Drama     Year                                2011
# 537   Comedy     Year                                2008
# 538   comedy     Year                                2009
#
# [539 rows x 3 columns]

# %%
pd.melt(frame =df,id_vars =['Year'],value_vars = ['Genre'])
# Out:
#     Year variable    value
# 0   2008    Genre  Romance
# 1   2010    Genre   Comedy
# 2   2010    Genre   Comedy
# 3   2010    Genre   Comedy
# 4   2008    Genre   Comedy
# ..   ...      ...      ...
# 72  2007    Genre  romance
# 73  2009    Genre    Drama
# 74  2011    Genre    Drama
# 75  2008    Genre   Comedy
# 76  2009    Genre   comedy
#
# [77 rows x 3 columns]

# %%
pd.melt(frame =df,id_vars =['Year'],value_vars = ['Rotten Tomatoes %'])
# Out:
#     Year           variable  value
# 0   2008  Rotten Tomatoes %     64
# 1   2010  Rotten Tomatoes %     68
# 2   2010  Rotten Tomatoes %     43
# 3   2010  Rotten Tomatoes %     15
# 4   2008  Rotten Tomatoes %     28
# ..   ...                ...    ...
# 72  2007  Rotten Tomatoes %     54
# 73  2009  Rotten Tomatoes %     89
# 74  2011  Rotten Tomatoes %     79
# 75  2008  Rotten Tomatoes %     40
# 76  2009  Rotten Tomatoes %     87
#
# [77 rows x 3 columns]

# %%
pd.melt(frame =df,id_vars =['Year'],value_vars = ['Rotten Tomatoes %'],var_name = 'Catergory')
# Out:
#     Year          Catergory  value
# 0   2008  Rotten Tomatoes %     64
# 1   2010  Rotten Tomatoes %     68
# 2   2010  Rotten Tomatoes %     43
# 3   2010  Rotten Tomatoes %     15
# 4   2008  Rotten Tomatoes %     28
# ..   ...                ...    ...
# 72  2007  Rotten Tomatoes %     54
# 73  2009  Rotten Tomatoes %     89
# 74  2011  Rotten Tomatoes %     79
# 75  2008  Rotten Tomatoes %     40
# 76  2009  Rotten Tomatoes %     87
#
# [77 rows x 3 columns]

# %%
pd.melt(frame =df,id_vars =['Year'],value_vars = ['Rotten Tomatoes %'],var_name = 'Catergory',value_name='Data')
# Out:
#     Year          Catergory  Data
# 0   2008  Rotten Tomatoes %    64
# 1   2010  Rotten Tomatoes %    68
# 2   2010  Rotten Tomatoes %    43
# 3   2010  Rotten Tomatoes %    15
# 4   2008  Rotten Tomatoes %    28
# ..   ...                ...   ...
# 72  2007  Rotten Tomatoes %    54
# 73  2009  Rotten Tomatoes %    89
# 74  2011  Rotten Tomatoes %    79
# 75  2008  Rotten Tomatoes %    40
# 76  2009  Rotten Tomatoes %    87
#
# [77 rows x 3 columns]
