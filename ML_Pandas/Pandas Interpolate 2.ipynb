# %%
import pandas as pd

# %%
df = pd.read_csv("D:\CSV\student_results - Copy.csv")
df
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020         NaN     10          3             8
# 3  6/3/2020         NaN     11          0            10
# 4  9/3/2020         NaN     15          4             7
# 5  5/4/2020         NaN     11         10             7
# 6  6/5/2020         NaN     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5        50.0
# 1                       2                 0         NaN
# 2                       2                 4        60.0
# 3                       1                 5        45.0
# 4                       2                 0        75.0
# ...

# %%
df.interpolate()
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020      1004.0     11          0            10
# 4  9/3/2020      1005.0     15          4             7
# 5  5/4/2020      1006.0     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df.dtypes # Before using axis = 1 we have to cheak that no dataframe is object type if it object type then we have to change it.
# Out:
# Date                       object
# Student ID                float64
# Class                       int64
# Study hrs                   int64
# Sleeping hrs                int64
# Social Media usage hrs      int64
# Mobile Games hrs            int64
# Percantege                float64
# dtype: object

# %%
# here Date object type of adata frame .

# %%
df.interpolate(limit = 3, method = 'linear')
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020      1004.0     11          0            10
# 4  9/3/2020      1005.0     15          4             7
# 5  5/4/2020         NaN     11         10             7
# 6  6/5/2020         NaN     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df.interpolate(limit_direction = 'backward')
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020      1004.0     11          0            10
# 4  9/3/2020      1005.0     15          4             7
# 5  5/4/2020      1006.0     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df.interpolate(limit = 1,limit_direction = 'backward')
# here limit = 1 so one NaN value is filled backward.
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020         NaN     10          3             8
# 3  6/3/2020         NaN     11          0            10
# 4  9/3/2020         NaN     15          4             7
# 5  5/4/2020         NaN     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df.interpolate(limit = 1,limit_direction = 'both')
# here one value filled forward and other value filled backword
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020         NaN     11          0            10
# 4  9/3/2020         NaN     15          4             7
# 5  5/4/2020         NaN     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020         NaN     10          3             8
# 3  6/3/2020         NaN     11          0            10
# 4  9/3/2020         NaN     15          4             7
# 5  5/4/2020         NaN     11         10             7
# 6  6/5/2020         NaN     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5        50.0
# 1                       2                 0         NaN
# 2                       2                 4        60.0
# 3                       1                 5        45.0
# 4                       2                 0        75.0
# ...

# %%
df.interpolate(limit_area = 'inside')
# all missing value is filled in specific inside area.
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020      1004.0     11          0            10
# 4  9/3/2020      1005.0     15          4             7
# 5  5/4/2020      1006.0     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df.interpolate(limit_area = 'outside')
# No missing value is filled  because specific area we choosen is ouside the data set
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020         NaN     10          3             8
# 3  6/3/2020         NaN     11          0            10
# 4  9/3/2020         NaN     15          4             7
# 5  5/4/2020         NaN     11         10             7
# 6  6/5/2020         NaN     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5        50.0
# 1                       2                 0         NaN
# 2                       2                 4        60.0
# 3                       1                 5        45.0
# 4                       2                 0        75.0
# ...

# %%
df.interpolate(inplace = True) # By default it takes linear parameter.
df
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020      1004.0     11          0            10
# 4  9/3/2020      1005.0     15          4             7
# 5  5/4/2020      1006.0     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...

# %%
df 
# Here we already use Inplace = True so it modify the same data frame and update the value.
# Out:
#        Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0  1/2/2020      1001.0     10          2             9
# 1  5/2/2020      1002.0     10          6             8
# 2  1/3/2020      1003.0     10          3             8
# 3  6/3/2020      1004.0     11          0            10
# 4  9/3/2020      1005.0     15          4             7
# 5  5/4/2020      1006.0     11         10             7
# 6  6/5/2020      1007.0     16          4             6
# 7  8/5/2020      1008.0     12         10             6
# 8  6/7/2020      1009.0     12          2             8
# 9  8/9/2020      1010.0     12          6             9
#
#    Social Media usage hrs  Mobile Games hrs  Percantege
# 0                       3                 5       50.00
# 1                       2                 0       55.00
# 2                       2                 4       60.00
# 3                       1                 5       45.00
# 4                       2                 0       75.00
# ...
