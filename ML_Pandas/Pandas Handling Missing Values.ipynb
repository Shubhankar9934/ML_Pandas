# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv')
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2   no        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4  yes         Mattouch          IT Services     2013.0  $14,026,934
# 4   5  yes        Techdrill        not available        NaN  $10,573,990
# 5   6   no         Techline               Health     2006.0  $13,898,119
# 6   7  yes          Cityace               Health     2010.0   $9,254,614
# 7   8  yes   Kayelectronics                  NaN     2009.0   $9,451,943
# 8   9   no          Ganzlax          IT Services     2011.0  $14,001,180
# 9  10  yes      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv')
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2   no        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4  yes         Mattouch          IT Services     2013.0  $14,026,934
# 4   5  yes        Techdrill        not available        NaN  $10,573,990
# 5   6   no         Techline               Health     2006.0  $13,898,119
# 6   7  yes          Cityace               Health     2010.0   $9,254,614
# 7   8  yes   Kayelectronics            no values     2009.0   $9,451,943
# 8   9   no          Ganzlax          IT Services     2011.0  $14,001,180
# 9  10  yes      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %% [markdown]
# # na_values

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv', na_values=['not available'])
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2   no        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4  yes         Mattouch          IT Services     2013.0  $14,026,934
# 4   5  yes        Techdrill                  NaN        NaN  $10,573,990
# 5   6   no         Techline               Health     2006.0  $13,898,119
# 6   7  yes          Cityace               Health     2010.0   $9,254,614
# 7   8  yes   Kayelectronics            no values     2009.0   $9,451,943
# 8   9   no          Ganzlax          IT Services     2011.0  $14,001,180
# 9  10  yes      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses    Profit     Growth
# 0  6,482,465 Dollars   5274553        30%
# 1    916,455 Dollars  11412916        20%
# ...

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv',na_values=['not available','no values'])
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2   no        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4  yes         Mattouch          IT Services     2013.0  $14,026,934
# 4   5  yes        Techdrill                  NaN        NaN  $10,573,990
# 5   6   no         Techline               Health     2006.0  $13,898,119
# 6   7  yes          Cityace               Health     2010.0   $9,254,614
# 7   8  yes   Kayelectronics                  NaN     2009.0   $9,451,943
# 8   9   no          Ganzlax          IT Services     2011.0  $14,001,180
# 9  10  yes      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv')
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2   no        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4  yes         Mattouch          IT Services     2013.0  $14,026,934
# 4   5  yes        Techdrill        not available        NaN  $10,573,990
# 5   6   no         Techline               Health     2006.0  $13,898,119
# 6   7  yes          Cityace               Health     2010.0   $9,254,614
# 7   8  yes   Kayelectronics            no values     2009.0   $9,451,943
# 8   9   no          Ganzlax          IT Services     2011.0  $14,001,180
# 9  10  yes      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %% [markdown]
# # keep_default_na

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv',keep_default_na=False)
df
# Out:
#    ID data             Name             Industry Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services      2009  $11,757,018
# 1   2   no        Stripfind   Financial Services      2010  $12,329,371
# 2   3  yes  Canecorporation               Health      2012  $10,597,009
# 3   4  yes         Mattouch          IT Services      2013  $14,026,934
# 4   5  yes        Techdrill        not available            $10,573,990
# 5   6   no         Techline               Health      2006  $13,898,119
# 6   7  yes          Cityace               Health      2010   $9,254,614
# 7   8  yes   Kayelectronics            no values      2009   $9,451,943
# 8   9   no          Ganzlax          IT Services      2011  $14,001,180
# 9  10  yes      Trantraxlax  Government Services      2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10 - Copy.csv',keep_default_na=True)
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2   no        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4  yes         Mattouch          IT Services     2013.0  $14,026,934
# 4   5  yes        Techdrill        not available        NaN  $10,573,990
# 5   6   no         Techline               Health     2006.0  $13,898,119
# 6   7  yes          Cityace               Health     2010.0   $9,254,614
# 7   8  yes   Kayelectronics            no values     2009.0   $9,451,943
# 8   9   no          Ganzlax          IT Services     2011.0  $14,001,180
# 9  10  yes      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# ...

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10.csv')
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill               Health       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8  yes   Kayelectronics               Health       2009   $9,451,943
# 8   9   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10  yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %% [markdown]
# # na_filter

# %%
df=pd.read_csv('D:\\CSV\\Fortune_10.csv',na_filter=False) # it help us to boost the performance
df
# Out:
#    ID data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2   no        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill               Health       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7  yes          Cityace               Health       2010   $9,254,614
# 7   8  yes   Kayelectronics               Health       2009   $9,451,943
# 8   9   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10  yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...
